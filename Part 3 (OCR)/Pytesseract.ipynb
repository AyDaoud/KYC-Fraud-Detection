# %%
# !pip install pytesseract

# %%
# !pip install pytesseract
!#sudo apt-get install tesseract-ocr-eng
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lenovo\anaconda3\lib\site-packages)
# '#sudo' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
import cv2
import numpy as np
import pytesseract
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %%
def display(img,cmap='gray'):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
#!sudo apt-get install tesseract-ocr-eng  #for english
#!sudo apt-get install tesseract-ocr-ara  #for arabic
#!sudo apt-get install tesseract-ocr-fra  #for french (German)

# %%
outfile = open('test1.txt', 'a',encoding='utf-8')

pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\\tesseract.exe'   

img = cv2.imread('ID (2).jpg')
plt.imshow(img , cmap ='gray')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
th, threshed = cv2.threshold(gray, 127, 255, cv2.THRESH_TRUNC)
text1 = pytesseract.image_to_data(threshed,output_type='data.frame')
text2 = pytesseract.image_to_string((threshed), lang="ara")
print(text2)
outfile.write(text2)
outfile.close()
text = text1[text1.conf != -1]
lines = text.groupby('block_num')['text'].apply(list)
conf = text.groupby(['block_num'])['conf'].mean()
# Out:
# 5 الجمهورية التونسيةذ
# بطاقة التغريف الوطة
#
# 0077
# سب داود
# الم ايفن -
# اي الولادة 01 افريل 199
# عانبا الدوحة دولة قطر

# %%
#outfile = open('test.txt', 'a',encoding='utf-8')
pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\\tesseract.exe'   

img = cv2.imread('cin.png')
plt.imshow(img , cmap ='gray')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
th, threshed = cv2.threshold(gray, 127, 255, cv2.THRESH_TRUNC)
text1 = pytesseract.image_to_data(threshed,output_type='data.frame')
text2 = pytesseract.image_to_string((threshed), lang="ara")
print(text2)
#outfile.write(text2)
#outfile.close()
text = text1[text1.conf != -1]
lines = text.groupby('block_num')['text'].apply(list)

conf = text.groupby(['block_num'])['conf'].mean() 
# it works in python 3
#with open(filepath, 'w', encoding='utf-8') as f:
  # do stuff ...
  #f.close()
# Out:
# بطاقة التعريف البيومترية َ
# الاسم محمد بن صالح التونسي 21
#
# - مس المهنة عامل يومي
# العنوان نهج الفل تونس 1001
#
# بسر

# %% [markdown]
# # Formulaire

# %%
# get three names of people
name1 = input("Please enter a person's CIN: ")
name2 = input("Please enter a person's family name: ")
name3 = input("Please enter a person's Name: ")
name4 = input("Please enter a person's date of birth: ")
name5 = input("Please enter a person's place: ")

  # open the output file for writing. This will delete any existing data
outfile = open('formulaire.txt', 'w',encoding='utf-8')
outfile.write('الجمهورية التونسية' + '\n') 
outfile.write('بطاقة التغريف الوطنية' + '\n') 

  # save the names into the file
outfile.write(name1 + '\n')
outfile.write('اللقب'+ ' ' + name2 + '\n')
outfile.write('الاسم'+ ' ' + name3 + '\n')
outfile.write('تاريخ الولادة'+ ' ' + name4 + '\n')
outfile.write('مكانها'+ ' ' + name5 + '\n') 



  # close the file
outfile.close()

#call the main function
# Out:
# Please enter a person's CIN: 09890757
# Please enter a person's family name: aymen
# Please enter a person's Name: daoud
# Please enter a person's date of birth: 01/04/1999
# Please enter a person's place: doha

# %%
import filecmp 
import difflib

f1 = 'formulaire.txt'
f2 = 'test1.txt'
  
result = filecmp.cmp(f1, f2, shallow=True) 
print(result)
# Out:
# False

# %% [markdown]
# # card ID (english)

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\\tesseract.exe'   

img = cv2.imread('original.jpg')
plt.imshow(img , cmap ='gray')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
th, threshed = cv2.threshold(gray, 127, 255, cv2.THRESH_TRUNC)
text1 = pytesseract.image_to_data(threshed,output_type='data.frame')
text2 = pytesseract.image_to_string((threshed), lang="eng")
print(text2)
text = text1[text1.conf != -1]
lines = text.groupby('block_num')['text'].apply(list)
conf = text.groupby(['block_num'])['conf'].mean()
# Out:
# DRIVER’S LICENSE
#
# «pun: 99 999 999 ours: 00
# pos: 08/04/1975
#
# sexe: 08/05/2023 iss: 03/01/2019
# * SAMPLE
# ? JANICE ANN
# ° 123 MAIN STREET
# APT. 1
# HARRISBURG, PA 17101-0000
#
# (SSEX: Fo ‘is €ves: BRO
# ‘OHGT: 5'-06"
# 4 CLASS: C
#
# 4 /END: NONE
# ' ? RESTR: NONE
# anice Lom DD:123456789012
#
# 3 :
# 456789012345 @ ORGAN DONOR

# %% [markdown]
# # carte d 'identité

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\\tesseract.exe'   

img = cv2.imread('IDfr.jpg')
plt.imshow(img , cmap ='gray')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
th, threshed = cv2.threshold(gray, 127, 255, cv2.THRESH_TRUNC)
text1 = pytesseract.image_to_data(threshed,output_type='data.frame')
text2 = pytesseract.image_to_string((threshed), lang="fra")
print(text2)
text = text1[text1.conf != -1]
lines = text.groupby('block_num')['text'].apply(list)
conf = text.groupby(['block_num'])['conf'].mean()
# Out:
# 5 RÉPUBLIQUE FRANÇAISE ä
#
# MARTIN
#
# }\‘Âa{y: Gaëlle, Marie
#
# Ë FRA 13 071990
#
# PARIS
#
# NOM D'USAGE
#
# X4RTBPFW4 1022030
#
# 384213
